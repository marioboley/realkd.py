# %% [markdown]
# # Creating an numba-compatible sorted array intersection algorithm
# In order to apply just in time compilation with numba to a function, all functions that are called in that funcion must also be compatible with numba.
#
# `sortednp.intersect` is one example of a non-compatible function which is used in the core of the greedysearch algorithm that we aim to convert to be numba-compatible. This notebook aims to propose and test a numba-compatible (specifically nopython mode) algoritm with performance as close to `sortednp.intersect` as possible.

# %%
import sortednp as snp

# %%
import sortednp as snp
import numpy as np
from numba import njit, int64
from numba.typed import List

@njit
def intersect_sorted_array(A, B):
  """
  ** NOTE: WILL ALTER LISTS PASSED TO IT **
  Returns the sorted intersection of A and B
  - Assumes A and B are sorted in reverse order (i.e. [100, 34, 2])
  - Assumes A and B each have no duplicates
  """
  intersection = List.empty_list(int64)

  if not len(A) or not len(B):
    return intersection

  a = A.pop()
  b = B.pop()
  while len(A) and len(B):
    if a == b:
        intersection.append(a)
        a = A.pop()
        b = B.pop()
    elif a > b:
        a = A.pop()
    else:
        b = B.pop()
  
  intersection.reverse()
  return intersection

def snp_intersect(A, B):
  return snp.intersect(A, B)


RNG = np.random.default_rng(0)
BASE_DENSITY = 1/3

def numba_listify(arr):
  return List(arr)

def generate_test_data(number_to_generate, density, as_numba_list=False):
  test_data = np.sort(RNG.choice(number_to_generate*round(1/density), number_to_generate, replace=False))
  if as_numba_list:
    # test_data = np.flip(test_data)
    return List.empty_list(int64) if number_to_generate==0 else numba_listify(test_data)
  return np.sort(RNG.choice(number_to_generate*round(1/density), number_to_generate, replace=False))

# test_A_list = generate_test_data(100, BASE_DENSITY, as_numba_list=True)
# test_B_list = generate_test_data(100, BASE_DENSITY, as_numba_list=True)
# x = intersect_sorted_array(test_A_list, test_B_list)
# print(x)
# list(x)

# %%
RNG = np.random.default_rng(0)
BASE_DENSITY = 1/3

def numba_listify(arr):
  return List(arr)

def generate_test_data(number_to_generate, density, as_numba_list=False):
  test_data = np.sort(RNG.choice(number_to_generate*round(1/density), number_to_generate, replace=False))
  if as_numba_list:
    # test_data = np.flip(test_data)
    return List.empty_list(int64) if number_to_generate==0 else numba_listify(test_data)
  return np.sort(RNG.choice(number_to_generate*round(1/density), number_to_generate, replace=False))

test_A_list = generate_test_data(100000, BASE_DENSITY, as_numba_list=True)
test_B_list = generate_test_data(100000, BASE_DENSITY, as_numba_list=True)
x = intersect_sorted_array(test_A_list, test_B_list)
print(x)
list(x)
# Out:
# [3, 8, 16, 18, 44, 59, 63, 91, 93, 112, 118, 126, 145, 158, 170, 177, 184, 188, 208, 228, 235, 240, 265, 268, 272, 273, 274, 283, 287, 293, 310, 334, 336, 339, 359, 372, 393, 412, 415, 422, 426, 428, 439, 446, 453, 465, 486, 493, 519, 535, 536, 562, 572, 594, 625, 632, 635, 639, 642, 644, 647, 651, 657, 659, 669, 678, 688, 716, 735, 739, 745, 756, 765, 781, 792, 802, 803, 804, 806, 829, 846, 847, 849, 850, 880, 904, 906, 920, 927, 939, 943, 953, 984, 988, 1008, 1016, 1021, 1036, 1047, 1054, 1056, 1083, 1087, 1092, 1093, 1099, 1136, 1148, 1150, 1152, 1153, 1156, 1165, 1175, 1199, 1204, 1227, 1230, 1242, 1248, 1250, 1255, 1262, 1268, 1281, 1308, 1316, 1318, 1319, 1326, 1337, 1346, 1353, 1357, 1378, 1389, 1392, 1397, 1411, 1431, 1434, 1440, 1452, 1456, 1460, 1469, 1497, 1522, 1526, 1549, 1557, 1564, 1566, 1569, 1576, 1584, 1589, 1590, 1593, 1602, 1608, 1624, 1630, 1639, 1645, 1653, 1656, 1666, 1671, 1682, 1684, 1708, 1712, 1717, 1720, 1728, 1734, 1735, 1745, 1746, 1750, 1755, 1767, 1781, 1783, 1793, 1794, 1813, 1815, 1833, 1839, 1845, 1846, 1864, 1879, 1883, 1896, 1899, 1903, 1910, 1917, 1930, 1949, 1959, 1967, 1970, 1978, 1987, 1989, 1999, 2009, 2011, 2029, 2039, 2050, 2062, 2069, 2080, 2085, 2097, 2107, 2108, 2123, 2124, 2125, 2135, 2150, 2163, 2177, 2182, 2186, 2197, 2201, 2206, 2211, 2232, 2244, 2248, 2249, 2256, 2265, 2273, 2275, 2286, 2288, 2304, 2327, 2330, 2353, 2357, 2364, 2371, 2391, 2397, 2399, 2457, 2459, 2464, 2465, 2484, 2512, 2513, 2519, 2536, 2537, 2561, 2564, 2567, 2578, 2604, 2627, 2634, 2647, 2659, 2663, 2667, 2746, 2766, 2775, 2792, 2794, 2812, 2825, 2840, 2867, 2875, 2879, 2881, 2882, 2884, 2885, 2891, 2926, 2937, 2952, 2969, 2970, 2978, 2986, 2994, 2997, 3030, 3035, 3044, 3057, 3064, 3078, 3130, 3148, 3150, 3151, 3159, 3165, 3172, 3176, 3177, 3188, 3208, 3220, 3229, 3232, 3233, 3249, 3251, 3253, 3273, 3275, 3278, 3287, 3292, 3295, 3298, 3304, 3306, 3313, 3322, 3335, 3336, 3346, 3371, 3372, 3375, 3392, 3398, 3401, 3412, 3416, 3423, 3433, 3443, 3445, 3447, 3449, 3471, 3476, 3483, 3507, 3516, 3520, 3523, 3529, 3535, 3538, 3543, 3552, 3569, 3608, 3635, 3637, 3638, 3652, 3659, 3661, 3662, 3679, 3687, 3701, 3709, 3710, 3712, 3722, 3735, 3737, 3740, 3744, 3759, 3760, 3762, 3765, 3769, 3777, 3782, 3799, 3811, 3818, 3846, 3859, 3862, 3865, 3875, 3876, 3898, 3902, 3903, 3928, 3930, 3937, 3963, 3965, 3976, 3979, 3987, 3992, 4001, 4023, 4042, 4045, 4046, 4057, 4059, 4062, 4065, 4072, 4074, 4086, 4088, 4092, 4112, 4140, 4144, 4155, 4156, 4158, 4163, 4165, 4184, 4185, 4186, 4193, 4202, 4212, 4218, 4231, 4249, 4250, 4258, 4275, 4278, 4280, 4288, 4311, 4316, 4323, 4331, 4345, 4370, 4375, 4388, 4391, 4401, 4409, 4413, 4422, 4425, 4434, 4456, 4459, 4464, 4468, 4473, 4477, 4478, 4493, 4504, 4512, 4532, 4539, 4541, 4542, 4545, 4559, 4569, 4572, 4573, 4577, 4582, 4586, 4587, 4592, 4595, 4599, 4618, 4645, 4651, 4680, 4686, 4702, 4707, 4710, 4719, 4729, 4732, 4734, 4744, 4746, 4788, 4789, 4800, 4807, 4808, 4812, 4814, 4840, 4849, 4858, 4881, 4883, 4891, 4902, 4930, 4935, 4957, 4966, 4981, 4998, 5004, 5032, 5038, 5044, 5069, 5075, 5092, 5107, 5124, 5127, 5144, 5146, 5150, 5159, 5164, 5168, 5172, 5173, 5184, 5187, 5206, 5207, 5227, 5230, 5240, 5279, 5280, 5307, 5310, 5326, 5330, 5347, 5355, 5358, 5377, 5383, 5390, 5392, 5405, 5441, 5464, 5465, 5471, 5477, 5491, 5492, 5498, 5505, 5510, 5523, 5524, 5526, 5541, 5543, 5549, 5557, 5566, 5576, 5579, 5589, 5592, 5609, 5611, 5612, 5634, 5642, 5649, 5652, 5664, 5693, 5696, 5697, 5702, 5711, 5712, 5716, 5720, 5752, 5756, 5766, 5772, 5791, 5821, 5844, 5849, 5856, 5858, 5863, 5874, 5881, 5886, 5887, 5897, 5902, 5922, 5929, 5933, 5944, 5949, 5953, 5957, 5967, 5979, 5987, 6003, 6005, 6016, 6043, 6052, 6064, 6066, 6072, 6080, 6081, 6082, 6083, 6090, 6095, 6101, 6125, 6141, 6142, 6155, 6156, 6162, 6171, 6203, 6208, 6239, 6251, 6268, 6277, 6280, 6282, 6292, 6294, 6305, 6317, 6331, 6357, 6359, 6379, 6380, 6386, 6397, 6412, 6416, 6424, 6440, 6444, 6449, 6463, 6469, 6485, 6489, 6500, 6516, 6517, 6529,  ...
# [3,
#  8,
#  16,
#  18,
#  44,
#  59,
#  63,
#  91,
#  93,
#  112,
#  118,
#  126,
#  145,
#  158,
#  170,
#  177,
#  184,
#  188,
#  208,
#  228,
#  235,
#  240,
#  265,
#  268,
#  272,
#  273,
#  274,
#  283,
#  287,
#  293,
#  310,
#  334,
#  336,
#  339,
#  359,
#  372,
#  393,
#  412,
#  415,
#  422,
#  426,
#  428,
#  439,
#  446,
#  453,
#  465,
#  486,
#  493,
#  519,
#  535,
#  536,
#  562,
#  572,
#  594,
#  625,
#  632,
#  635,
#  639,
#  642,
#  644,
#  647,
#  651,
#  657,
#  659,
#  669,
#  678,
#  688,
#  716,
#  735,
#  739,
#  745,
#  756,
#  765,
#  781,
#  792,
#  802,
#  803,
#  804,
#  806,
#  829,
#  846,
#  847,
#  849,
#  850,
#  880,
#  904,
#  906,
#  920,
#  927,
#  939,
#  943,
#  953,
#  984,
#  988,
#  1008,
#  1016,
#  1021,
#  1036,
#  1047,
#  1054,
#  1056,
#  1083,
#  1087,
#  1092,
#  1093,
#  1099,
#  1136,
#  1148,
#  1150,
#  1152,
#  1153,
#  1156,
#  1165,
#  1175,
#  1199,
#  1204,
#  1227,
#  1230,
#  1242,
#  1248,
#  1250,
#  1255,
#  1262,
#  1268,
#  1281,
#  1308,
#  1316,
#  1318,
#  1319,
#  1326,
#  1337,
#  1346,
#  1353,
#  1357,
#  1378,
#  1389,
#  1392,
#  1397,
#  1411,
#  1431,
#  1434,
#  1440,
#  1452,
#  1456,
#  1460,
#  1469,
#  1497,
#  1522,
#  1526,
#  1549,
#  1557,
#  1564,
#  1566,
#  1569,
#  1576,
#  1584,
#  1589,
#  1590,
#  1593,
#  1602,
#  1608,
#  1624,
#  1630,
#  1639,
#  1645,
#  1653,
#  1656,
#  1666,
#  1671,
#  1682,
#  1684,
#  1708,
#  1712,
#  1717,
#  1720,
#  1728,
#  1734,
#  1735,
#  1745,
#  1746,
#  1750,
#  1755,
#  1767,
#  1781,
#  1783,
#  1793,
#  1794,
#  1813,
#  1815,
#  1833,
#  1839,
#  1845,
#  1846,
#  1864,
#  1879,
#  1883,
#  1896,
#  1899,
#  1903,
#  1910,
#  1917,
#  1930,
#  1949,
#  1959,
#  1967,
#  1970,
#  1978,
#  1987,
#  1989,
#  1999,
#  2009,
#  2011,
#  2029,
#  2039,
#  2050,
#  2062,
#  2069,
#  2080,
#  2085,
#  2097,
#  2107,
#  2108,
#  2123,
#  2124,
#  2125,
#  2135,
#  2150,
#  2163,
#  2177,
#  2182,
#  2186,
#  2197,
#  2201,
#  2206,
#  2211,
#  2232,
#  2244,
#  2248,
#  2249,
#  2256,
#  2265,
#  2273,
#  2275,
#  2286,
#  2288,
#  2304,
#  2327,
#  2330,
#  2353,
#  2357,
#  2364,
#  2371,
#  2391,
#  2397,
#  2399,
#  2457,
#  2459,
#  2464,
#  2465,
#  2484,
#  2512,
#  2513,
#  2519,
#  2536,
#  2537,
#  2561,
#  2564,
#  2567,
#  2578,
#  2604,
#  2627,
#  2634,
#  2647,
#  2659,
#  2663,
#  2667,
#  2746,
#  2766,
#  2775,
#  2792,
#  2794,
#  2812,
#  2825,
#  2840,
#  2867,
#  2875,
#  2879,
#  2881,
#  2882,
#  2884,
#  2885,
#  2891,
#  2926,
#  2937,
#  2952,
#  2969,
#  2970,
#  2978,
#  2986,
#  2994,
#  2997,
#  3030,
#  3035,
#  3044,
#  3057,
#  3064,
#  3078,
#  3130,
#  3148,
#  3150,
#  3151,
#  3159,
#  3165,
#  3172,
#  3176,
#  3177,
#  3188,
#  3208,
#  3220,
#  3229,
#  3232,
#  3233,
#  3249,
#  3251,
#  3253,
#  3273,
#  3275,
#  3278,
#  3287,
#  3292,
#  3295,
#  3298,
#  3304,
#  3306,
#  3313,
#  3322,
#  3335,
#  3336,
#  3346,
#  3371,
#  3372,
#  3375,
#  3392,
#  3398,
#  3401,
#  3412,
#  3416,
#  3423,
#  3433,
#  3443,
#  3445,
#  3447,
#  3449,
#  3471,
#  3476,
#  3483,
#  3507,
#  3516,
#  3520,
#  3523,
#  3529,
#  3535,
#  3538,
#  3543,
#  3552,
#  3569,
#  3608,
#  3635,
#  3637,
#  3638,
#  3652,
#  3659,
#  3661,
#  3662,
#  3679,
#  3687,
#  3701,
#  3709,
#  3710,
#  3712,
#  3722,
#  3735,
#  3737,
#  3740,
#  3744,
#  3759,
#  3760,
#  3762,
#  3765,
#  3769,
#  3777,
#  3782,
#  3799,
#  3811,
#  3818,
#  3846,
#  3859,
#  3862,
#  3865,
#  3875,
#  3876,
#  3898,
#  3902,
#  3903,
#  3928,
#  3930,
#  3937,
#  3963,
#  3965,
#  3976,
#  3979,
#  3987,
#  3992,
#  4001,
#  4023,
#  4042,
#  4045,
#  4046,
#  4057,
#  4059,
#  4062,
#  4065,
#  4072,
#  4074,
#  4086,
#  4088,
#  4092,
#  4112,
#  4140,
#  4144,
#  4155,
#  4156,
#  4158,
#  4163,
#  4165,
#  4184,
#  4185,
#  4186,
#  4193,
#  4202,
#  4212,
#  4218,
#  4231,
#  4249,
#  4250,
#  4258,
#  4275,
#  4278,
#  4280,
#  4288,
#  4311,
#  4316,
#  4323,
#  4331,
#  4345,
#  4370,
#  4375,
#  4388,
#  4391,
#  4401,
#  4409,
#  4413,
#  4422,
#  4425,
#  4434,
#  4456,
#  4459,
#  4464,
#  4468,
#  4473,
#  4477,
#  4478,
#  4493,
#  4504,
#  4512,
#  4532,
#  4539,
#  4541,
#  4542,
#  4545,
#  4559,
#  4569,
#  4572,
#  4573,
#  4577,
#  4582,
#  4586,
#  4587,
#  4592,
#  4595,
#  4599,
#  4618,
#  4645,
#  4651,
#  4680,
#  4686,
#  4702,
#  4707,
#  4710,
#  4719,
#  4729,
#  4732,
#  4734,
#  4744,
#  4746,
#  4788,
#  4789,
#  4800,
#  4807,
#  4808,
#  4812,
#  4814,
#  4840,
#  4849,
#  4858,
#  4881,
#  4883,
#  4891,
#  4902,
#  4930,
#  4935,
#  4957,
#  4966,
#  4981,
#  4998,
#  5004,
#  5032,
#  5038,
#  5044,
#  5069,
#  5075,
#  5092,
#  5107,
#  5124,
#  5127,
#  5144,
#  5146,
#  5150,
#  5159,
#  5164,
#  5168,
#  5172,
#  5173,
#  5184,
#  5187,
#  5206,
#  5207,
#  5227,
#  5230,
#  5240,
#  5279,
#  5280,
#  5307,
#  5310,
#  5326,
#  5330,
#  5347,
#  5355,
#  5358,
#  5377,
#  5383,
#  5390,
#  5392,
#  5405,
#  5441,
#  5464,
#  5465,
#  5471,
#  5477,
#  5491,
#  5492,
#  5498,
#  5505,
#  5510,
#  5523,
#  5524,
#  5526,
#  5541,
#  5543,
#  5549,
#  5557,
#  5566,
#  5576,
#  5579,
#  5589,
#  5592,
#  5609,
#  5611,
#  5612,
#  5634,
#  5642,
#  5649,
#  5652,
#  5664,
#  5693,
#  5696,
#  5697,
#  5702,
#  5711,
#  5712,
#  5716,
#  5720,
#  5752,
#  5756,
#  5766,
#  5772,
#  5791,
#  5821,
#  5844,
#  5849,
#  5856,
#  5858,
#  5863,
#  5874,
#  5881,
#  5886,
#  5887,
#  5897,
#  5902,
#  5922,
#  5929,
#  5933,
#  5944,
#  5949,
#  5953,
#  5957,
#  5967,
#  5979,
#  5987,
#  6003,
#  6005,
#  6016,
#  6043,
#  6052,
#  6064,
#  6066,
#  6072,
#  6080,
#  6081,
#  6082,
#  6083,
#  6090,
#  6095,
#  6101,
#  6125,
#  6141,
#  6142,
#  6155,
#  6156,
#  6162,
#  6171,
#  6203,
#  6208,
#  6239,
#  6251,
#  6268,
#  6277,
#  6280,
#  6282,
#  6292,
#  6294,
#  6305,
#  6317,
#  6331,
#  6357,
#  6359,
#  6379,
#  6380,
#  6386,
#  6397,
#  6412,
#  6416,
#  6424,
#  6440,
#  6444,
#  6449,
#  6463,
#  6469,
#  6485,
#  6489,
#  6500,
#  6516,
#  6517,
#  6529,
#  6547,
#  6557,
#  6561,
#  6568,
#  6580,
#  6586,
#  6592,
#  6603,
#  6613,
#  6615,
#  6621,
#  6627,
#  6628,
#  6664,
#  6667,
#  6670,
#  6680,
#  6681,
#  6687,
#  6694,
#  6696,
#  6707,
#  6734,
#  6762,
#  6763,
#  6772,
#  6792,
#  6804,
#  6813,
#  6828,
#  6837,
#  6843,
#  6844,
#  6849,
#  6864,
#  6867,
#  6873,
#  6878,
#  6884,
#  6902,
#  6916,
#  6921,
#  6929,
#  6936,
#  6937,
#  6938,
#  6942,
#  6946,
#  6970,
#  6980,
#  6985,
#  6990,
#  6992,
#  7004,
#  7010,
#  7017,
#  7039,
#  7044,
#  7050,
#  7065,
#  7066,
#  7081,
#  7082,
#  7092,
#  7103,
#  7109,
#  7118,
#  7127,
#  7137,
#  7141,
#  7152,
#  7154,
#  7157,
#  7159,
#  7163,
#  7187,
#  7191,
#  7196,
#  7202,
#  7221,
#  7222,
#  7239,
#  7247,
#  7250,
#  7254,
#  7257,
#  7258,
#  7270,
#  7278,
#  7301,
#  7311,
#  7312,
#  7316,
#  7323,
#  7325,
#  7334,
#  7337,
#  7351,
#  7353,
#  7373,
#  7382,
#  7385,
#  7386,
#  7391,
#  7406,
#  7412,
#  7415,
#  7416,
#  7417,
#  7431,
#  7435,
#  7445,
#  7456,
#  7467,
#  7505,
#  7519,
#  7529,
#  7533,
#  7540,
#  7542,
#  7547,
#  7555,
#  7558,
#  7569,
#  7576,
#  7588,
#  7606,
#  7609,
#  7611,
#  7622,
#  7623,
#  7625,
#  7657,
#  7669,
#  7675,
#  7684,
#  7695,
#  7704,
#  7705,
#  7706,
#  7710,
#  7711,
#  7718,
#  7728,
#  7735,
#  7764,
#  7765,
#  7785,
#  7808,
#  7819,
#  7821,
#  7831,
#  7835,
#  7855,
#  7869,
#  7871,
#  7884,
#  7886,
#  7900,
#  7906,
#  7912,
#  7914,
#  7915,
#  7916,
#  7937,
#  7949,
#  7972,
#  7975,
#  7978,
#  7992,
#  8012,
#  8015,
#  8031,
#  8032,
#  8037,
#  8039,
#  8075,
#  8078,
#  8090,
#  8095,
#  8098,
#  8101,
#  8103,
#  8108,
#  8112,
#  8123,
#  8143,
#  8158,
#  8161,
#  8165,
#  8166,
#  8168,
#  8170,
#  8175,
#  8186,
#  8200,
#  8203,
#  8229,
#  8235,
#  8246,
#  8248,
#  8263,
#  8283,
#  8317,
#  8325,
#  8336,
#  8351,
#  8354,
#  8367,
#  8370,
#  8378,
#  8413,
#  8422,
#  8439,
#  8479,
#  8488,
#  8517,
#  8519,
#  8533,
#  8540,
#  8543,
#  8553,
#  8571,
#  8592,
#  8596,
#  8616,
#  8628,
#  8630,
#  8631,
#  8637,
#  8644,
#  8647,
#  8648,
#  8658,
#  8659,
#  8665,
#  8672,
#  8674,
#  8687,
#  8692,
#  8694,
#  8700,
#  8705,
#  8723,
#  8730,
#  8742,
#  8747,
#  8748,
#  8752,
#  8753,
#  8766,
#  8782,
#  8795,
#  8805,
#  8806,
#  8814,
#  8828,
#  8829,
#  8832,
#  8853,
#  8881,
#  8882,
#  8889,
#  8891,
#  8893,
#  8904,
#  8905,
#  8911,
#  8927,
#  8930,
#  8931,
#  8942,
#  8944,
#  8952,
#  8966,
#  8968,
#  8979,
#  8981,
#  8982,
#  8985,
#  8993,
#  8996,
#  8997,
#  9012,
#  9027,
#  9041,
#  9045,
#  9052,
#  9060,
#  9066,
#  9069,
#  9077,
#  9081,
#  9086,
#  9103,
#  9108,
#  9113,
#  9128,
#  9129,
#  9145,
#  9147,
#  9158,
#  9165,
#  9166,
#  9168,
#  9177,
#  9182,
#  9184,
#  9193,
#  9194,
#  9207,
#  9217,
#  9230,
#  9236,
#  9237,
#  9246,
#  ...]

# %%
# from timeit import repeat, timeit
from math import floor, log, log10, log2, sqrt
import timeit

from matplotlib import test

ns_to_plot = list(range(0, 10000, 1000)) + list(range(10000, 100000, 10000))
densities_to_plot = [2/x for x in range(2, 12, 1)][::-1]

# Took 30min for LOOPS_PER_RUN=200, RUNS_PER_REPEAT=7, NUM_REPEATS=21
LOOPS_PER_RUN=100
NUM_REPEATS=5
RUNS_PER_REPEAT=5
BASE_N = 90_000
BASE_DENSITY = 1/3

benchmark_configs = [
  {
    'name': 'benchmarks_balanced',
    'display': {
      'title': 'Array A: n elements, Array B: n elements',
      'xlabel': '$n$ (density = 1/3)'
    },
    'iterator': ns_to_plot,
    'config': {
      'n': '$i',
      'm': '$i',
      'density': BASE_DENSITY
    }
  },
  {
    'name': 'benchmarks_small_m',
    'display': {
      'title': 'Array A: 999 elements, Array B: n elements',
      'xlabel': '$n$ (density = 1/3)'
    },
    'iterator': ns_to_plot,
    'config': {
      'n': '$i',
      'm': 999,
      'density': BASE_DENSITY
    }
  },
  {
    'name': 'benchmarks_large_m',
    'display': {
      'title': 'Array A: 100,000 elements, Array B: n elements',
      'xlabel': '$n$ (density = 1/3)'
    },
    'iterator': ns_to_plot,
    'config': {
      'n': '$i',
      'm': 100_000,
      'density': BASE_DENSITY
    }
  },
  {
    'name': 'benchmarks_density',
    'display': {
      'title': 'Array A: n elements, Array B: n elements',
      'xlabel': 'density (n=90,000)'
    },
    'iterator': densities_to_plot,
    'config': {
      'n': BASE_N,
      'm': BASE_N,
      'density': '$i'
    }
  }
]

benchmark_results = {}

# Run all functions first to eliminate the effect of compilation
pre_test_A = generate_test_data(100, BASE_DENSITY)
pre_test_B = generate_test_data(100, BASE_DENSITY)
pre_test_A_list = generate_test_data(100, BASE_DENSITY, as_numba_list=True)
pre_test_B_list = generate_test_data(100, BASE_DENSITY, as_numba_list=True)
print(intersect_sorted_array(pre_test_A_list, pre_test_B_list))
snp_intersect(pre_test_A, pre_test_B)

for benchmark in benchmark_configs:
  print(benchmark['name'])
  benchmark_results[benchmark['name']] = {
    'intersect_sorted_array': {},
    'snp_intersect': {}
  }
  for i in benchmark['iterator']:
    for method in ['intersect_sorted_array', 'snp_intersect']:
      print(f'i={i}, method={method}:')
      n = i if benchmark['config']['n'] == '$i' else benchmark['config']['n']
      m = i if benchmark['config']['m'] == '$i' else benchmark['config']['m']
      density = i if benchmark['config']['density'] == '$i' else benchmark['config']['density']
      timeresults = []
      for repeat in range(NUM_REPEATS):
        test_A = generate_test_data(n, density, as_numba_list=(method == 'intersect_sorted_array'))
        test_B = generate_test_data(m, density, as_numba_list=(method == 'intersect_sorted_array'))
        timeresults.append(min(timeit.repeat(f'{method}(test_A, test_B)', repeat=RUNS_PER_REPEAT, number=LOOPS_PER_RUN, globals=globals())))
      benchmark_results[benchmark['name']][method][i] = timeresults
# Out:
# [15, 19, 39, 51, 55, 59, 61, 72, 83, 87, 100, 119, 137, 146, 166, 175, 177, 183, 190, 202, 213, 229, 238, 253, 256, 261, 273, 283, 284, ...]
# benchmarks_balanced
# i=0, method=intersect_sorted_array:
# i=0, method=snp_intersect:
# i=1000, method=intersect_sorted_array:
# i=1000, method=snp_intersect:
# i=2000, method=intersect_sorted_array:
# i=2000, method=snp_intersect:
# i=3000, method=intersect_sorted_array:
# i=3000, method=snp_intersect:
# i=4000, method=intersect_sorted_array:
# i=4000, method=snp_intersect:
# i=5000, method=intersect_sorted_array:
# i=5000, method=snp_intersect:
# i=6000, method=intersect_sorted_array:
# i=6000, method=snp_intersect:
# i=7000, method=intersect_sorted_array:
# i=7000, method=snp_intersect:
# i=8000, method=intersect_sorted_array:
# i=8000, method=snp_intersect:
# i=9000, method=intersect_sorted_array:
# i=9000, method=snp_intersect:
# i=10000, method=intersect_sorted_array:
# i=10000, method=snp_intersect:
# i=20000, method=intersect_sorted_array:
# i=20000, method=snp_intersect:
# i=30000, method=intersect_sorted_array:
# i=30000, method=snp_intersect:
# i=40000, method=intersect_sorted_array:
# i=40000, method=snp_intersect:
# i=50000, method=intersect_sorted_array:
# i=50000, method=snp_intersect:
# i=60000, method=intersect_sorted_array:
# i=60000, method=snp_intersect:
# i=70000, method=intersect_sorted_array:
# i=70000, method=snp_intersect:
# i=80000, method=intersect_sorted_array:
# i=80000, method=snp_intersect:
# i=90000, method=intersect_sorted_array:
# i=90000, method=snp_intersect:
# benchmarks_small_m
# i=0, method=intersect_sorted_array:
# i=0, method=snp_intersect:
# i=1000, method=intersect_sorted_array:
# i=1000, method=snp_intersect:
# i=2000, method=intersect_sorted_array:
# i=2000, method=snp_intersect:
# i=3000, method=intersect_sorted_array:
# i=3000, method=snp_intersect:
# i=4000, method=intersect_sorted_array:
# i=4000, method=snp_intersect:
# i=5000, method=intersect_sorted_array:
# i=5000, method=snp_intersect:
# i=6000, method=intersect_sorted_array:
# i=6000, method=snp_intersect:
# i=7000, method=intersect_sorted_array:
# i=7000, method=snp_intersect:
# i=8000, method=intersect_sorted_array:
# i=8000, method=snp_intersect:
# i=9000, method=intersect_sorted_array:
# i=9000, method=snp_intersect:
# i=10000, method=intersect_sorted_array:
# i=10000, method=snp_intersect:
# i=20000, method=intersect_sorted_array:
# i=20000, method=snp_intersect:
# i=30000, method=intersect_sorted_array:
# i=30000, method=snp_intersect:
# i=40000, method=intersect_sorted_array:
# i=40000, method=snp_intersect:
# i=50000, method=intersect_sorted_array:
# i=50000, method=snp_intersect:
# i=60000, method=intersect_sorted_array:
# i=60000, method=snp_intersect:
# i=70000, method=intersect_sorted_array:
# i=70000, method=snp_intersect:
# i=80000, method=intersect_sorted_array:
# i=80000, method=snp_intersect:
# i=90000, method=intersect_sorted_array:
# i=90000, method=snp_intersect:
# benchmarks_large_m
# i=0, method=intersect_sorted_array:
# i=0, method=snp_intersect:
# i=1000, method=intersect_sorted_array:
# i=1000, method=snp_intersect:
# i=2000, method=intersect_sorted_array:
# i=2000, method=snp_intersect:
# i=3000, method=intersect_sorted_array:
# i=3000, method=snp_intersect:
# i=4000, method=intersect_sorted_array:
# i=4000, method=snp_intersect:
# i=5000, method=intersect_sorted_array:
# i=5000, method=snp_intersect:
# i=6000, method=intersect_sorted_array:
# i=6000, method=snp_intersect:
# i=7000, method=intersect_sorted_array:
# i=7000, method=snp_intersect:
# i=8000, method=intersect_sorted_array:
# i=8000, method=snp_intersect:
# i=9000, method=intersect_sorted_array:
# i=9000, method=snp_intersect:
# i=10000, method=intersect_sorted_array:
# i=10000, method=snp_intersect:
# i=20000, method=intersect_sorted_array:
# i=20000, method=snp_intersect:
# i=30000, method=intersect_sorted_array:
# i=30000, method=snp_intersect:
# i=40000, method=intersect_sorted_array:
# i=40000, method=snp_intersect:
# i=50000, method=intersect_sorted_array:
# i=50000, method=snp_intersect:
# i=60000, method=intersect_sorted_array:
# i=60000, method=snp_intersect:
# i=70000, method=intersect_sorted_array:
# i=70000, method=snp_intersect:
# i=80000, method=intersect_sorted_array:
# i=80000, method=snp_intersect:
# i=90000, method=intersect_sorted_array:
# i=90000, method=snp_intersect:
# benchmarks_density
# i=0.18181818181818182, method=intersect_sorted_array:
# i=0.18181818181818182, method=snp_intersect:
# i=0.2, method=intersect_sorted_array:
# i=0.2, method=snp_intersect:
# i=0.2222222222222222, method=intersect_sorted_array:
# i=0.2222222222222222, method=snp_intersect:
# i=0.25, method=intersect_sorted_array:
# i=0.25, method=snp_intersect:
# i=0.2857142857142857, method=intersect_sorted_array:
# i=0.2857142857142857, method=snp_intersect:
# i=0.3333333333333333, method=intersect_sorted_array:
# i=0.3333333333333333, method=snp_intersect:
# i=0.4, method=intersect_sorted_array:
# i=0.4, method=snp_intersect:
# i=0.5, method=intersect_sorted_array:
# i=0.5, method=snp_intersect:
# i=0.6666666666666666, method=intersect_sorted_array:
# i=0.6666666666666666, method=snp_intersect:
# i=1.0, method=intersect_sorted_array:
# i=1.0, method=snp_intersect:

# %%
from statistics import mean, stdev
from matplotlib.markers import MarkerStyle
import matplotlib.pyplot as plt
from numpy import average
label_to_colors = {
  'intersect_sorted_array': 'green',
  'snp_intersect': 'purple'
}
plt.subplots(1, 4, figsize=(20, 5))

plt.ylabel('time (seconds)')
for i, benchmark in enumerate(benchmark_configs):
  plt.subplot(1, 4, i+1)
  plt.xlim(benchmark['iterator'][0], benchmark['iterator'][-1])
  plt.title(benchmark['display']['title'])
  plt.xlabel(benchmark['display']['xlabel'])
  for label, time_result in benchmark_results[benchmark['name']].items():
    for i in benchmark['iterator']:
      plt.scatter([i]*NUM_REPEATS, time_result[i], c=label_to_colors[label], marker='.')
    plt.errorbar(benchmark['iterator'], [mean(time_result[i]) for i in benchmark['iterator']], yerr=[stdev(time_result[i]) for i in benchmark['iterator']], marker='', capsize=5.0, label=label, c=label_to_colors[label])
plt.legend()

plt.show()

# %% [markdown]
# For the following, assume we're intersecting an array with n elements and an array with m elements
#
# I looked into the implementation of sortednp.intersect and discovered it does the following:
#
# iterates over the smaller array, and for each item:
# - Search the larger list for it
#
# Therefore theoretically we'd expect it to take:
#    loop       search each loop
#    v          v
# O(min(n,m) * log(max(n, m)))
#
# When we fix m to be less than n (i.e. 20), we would then expect O(log(n)).
# In practice (by looking at the second graph above), we find this to be inconclusive. It's possible that it is O(log(n)), but equally possible that the time is constant.
#
#
# If we fix m to be more then n (i.e. 100000) we would expect the running time to be O(n)
# Looking at the third graph above, this looks likely.
#
# Final note:
# - There appears to be a disparity between the two algorithms when it comes to the density of the numbers (i.e a density of 1/2 and m=20 means that the 20 numbers are spread between 0 and 40)
